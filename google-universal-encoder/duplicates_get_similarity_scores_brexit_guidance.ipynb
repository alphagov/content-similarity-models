# %%
# import gensim
import collections
import random


import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import pairwise_distances_chunked, pairwise_distances


from tqdm import tnrange, tqdm_notebook


from itertools import compress

import time

# %% [markdown]
# ### Set-up and get data

# %% [markdown]
# As this notebook uses data derived from the [govuk-taxonomy-supervised-learning repo](https://github.com/alphagov/govuk-taxonomy-supervised-learning), we clone that. Given you are likely to perform this for a given date, we suggest you create a dir with the date of the format `dd-mm-yy` within the data folder of the aforementioned repo and point to the data folder therein as the DATADIR.
#
# For example:
#
# ```
# /Users/adalovelace/Documents/govuk-taxonomy-supervised-learning/data/11-02-19
# ```

# %%
DATADIR = os.getenv("DATADIR")

# %%
DATADIR
# Out:
# '/Users/ellieking/Documents/govuk-taxonomy-supervised-learning/data/2019-04-15'

# %% [markdown]
# Import vectors with same index as labelled. This may require some modification to match your filename.

# %%
embedded_sentences = np.load('embedded_clean_content'+os.path.basename(DATADIR)+'.npy')

# %% [markdown]
# The Google Universal Sentence Encoder model takes a word, sentence or a paragraph as input and outputs a 512-dimensional vector.

# %%
# rows, cols
embedded_sentences.shape
# Out:
# (242861, 512)

# %%
content = pd.read_csv(
    os.path.join(DATADIR, 'clean_content.csv'),
    low_memory=False)

# %%
content.shape
# Out:
# (242861, 11)

# %% [markdown]
# How many unique pieces of content are there on GOV.UK?

# %%
content.content_id.nunique()
# Out:
# 242861

# %% [markdown]
# ## Get brexit subset of content

# %%
text_file = open('brexit_url_prefixes.txt', 'r')
brexit_url_prefixes = text_file.read().split(',')
text_file.close()

# %%
len(brexit_url_prefixes)
# Out:
# 1998

# %% [markdown]
# ### there are some prefixes which are urls to subsections of guides
# For example, this set of prefixes would only be represented once in content

# %%
[prefix for prefix in brexit_url_prefixes if prefix.startswith('/settled-status-eu-citizens-families')]
# Out:
# ['/settled-status-eu-citizens-families/applying-for-settled-status',
#  '/settled-status-eu-citizens-families',
#  '/settled-status-eu-citizens-families/eligibility',
#  '/settled-status-eu-citizens-families/what-youll-need-to-apply',
#  '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means',
#  '/settled-status-eu-citizens-families/after-youve-applied',
#  '/settled-status-eu-citizens-families/if-you-have-permanent-residence-or-indefinite-leave-to-remain',
#  '/settled-status-eu-citizens-families/not-eu-eea-swiss-citizen',
#  '/settled-status-eu-citizens-families/apply-settled-status-for-child',
#  '/settled-status-eu-citizens-families/settled-status-less-than-5-years',
#  '/settled-status-eu-citizens-families/print',
#  '/settled-status-eu-citizens-families/when-to-apply',
#  '/settled-status-eu-citizens-families#brexit',
#  '/settled-status-eu-citizens-families/settled-status-if-youre-under-21',
#  '/settled-status-eu-citizens-families/',
#  '/settled-status-eu-citizens-families/what-youll-need-to-applyhttps://www.gov.uk/settled-status-eu-citizens-families/what-youll-need-to-apply',
#  '/settled-status-eu-citizens-families/applying-for-settled-status-eu-citizens-families/eligibility',
#  '/settled-status-eu-citizens-families/applying-for-settled-statushttps://www.gov.uk/settled-status-eu-citizens-families/applying-for-settled-status',
#  '/settled-status-eu-citizens-families/applying-for-settled-statushttps:/www.gov.uk/settled-status-eu-citizens-families/applying-for-settled-status']

# %%
len([prefix for prefix in brexit_url_prefixes if prefix.startswith('/settled-status-eu-citizens-families')])
# Out:
# 19

# %% [markdown]
# the base_path in content will only have the first part of this brexit_url. So to find these in content
#
# - First find which prefixes have duplicate first parts
# e.g,
# '/settled-status-eu-citizens-families'
# - Then truncate them to root path
# - Add truncated root paths to lookup list (brexit_url_prefixes)

# %%
def splitall(path):
    """split the prefix url into parts separated by /
    returns a list containing each string part of path"""
    allparts = []
    while 1:
        parts = os.path.split(path)
        if parts[0] == path:  # sentinel for absolute paths
            allparts.insert(0, parts[0])
            break
        elif parts[1] == path: # sentinel for relative paths
            allparts.insert(0, parts[1])
            break
        else:
            path = parts[0]
            allparts.insert(0, parts[1])
    return allparts

# %%
# capture the first two parts into a list if there are more than 2 (there are a handful that are just 2) e.g., '/staying-uk-eu-citizen'
first_2parts = []
for path in brexit_url_prefixes:
    parts = splitall(path)
    if len(parts) >2:
        first_2parts.append(parts[0]+parts[1])

# %%
len(first_2parts)
# Out:
# 1984

# %%
#find repeated items of the same truncated root path to identify the stem to search for in content
seen = {}
dupes = []

for x in first_2parts:
    if x not in seen:
        seen[x] = 1
    else:
        if seen[x] == 1:
            dupes.append(x)
        seen[x] += 1

# %%
#these are the repeated stems. But some of these should be there. So pluck the guides out manually
dupes
# Out:
# ['/settled-status-eu-citizens-families',
#  '/government',
#  '/guidance',
#  '/driving-abroad',
#  '/world',
#  '/eu-withdrawal-act-2018-statutory-instruments',
#  '/print',
#  '/prepare-eu-exit',
#  '/visit-europe-brexit']

# %%
#add the stems to the lookup list so they can be matched to content
brexit_url_prefixes = brexit_url_prefixes + ['/settled-status-eu-citizens-families',
 '/driving-abroad',
 '/eu-withdrawal-act-2018-statutory-instruments',
 '/prepare-eu-exit',
 '/visit-europe-brexit']

# %%
#create a brexit flag as a pandas col
content['brexit'] = np.where(content['base_path'].str.startswith(tuple(brexit_url_prefixes)), 1, 0)

# %%
#there are fewer than len(brexit_url_preifx) because the list has repeated content items in it
content.brexit.value_counts()
# Out:
# 0    241386
# 1      1475
# Name: brexit, dtype: int64

# %%
embedded_sentences_brexit = embedded_sentences[content.brexit==1]

# %% [markdown]
# ## Get guidance and publications subset

# %%
content.groupby(['document_type']).size()
# Out:
# document_type
# aaib_report                                8387
# answer                                      743
# asylum_support_decision                      74
# authored_article                            361
# business_finance_support_scheme             180
# calendar                                      2
# case_study                                 1716
# closed_consultation                         709
# cma_case                                   1928
# consultation_outcome                       3372
# correspondence                             4028
# countryside_stewardship_grant               244
# decision                                   4629
# detailed_guide                             5719
# document_collection                        4278
# drug_safety_update                          546
# employment_appeal_tribunal_decision        1115
# employment_tribunal_decision              27318
# esi_fund                                   1112
# export_health_certificate                  1435
# fatality_notice                             503
# foi_release                                8587
# form                                       5092
# government_response                         369
# guidance                                  21266
# guide                                       781
# hmrc_manual                                 224
# impact_assessment                           880
# independent_report                         2511
# international_development_fund               43
#                                           ...
# oral_statement                              478
# petitions_and_campaigns                       2
# place                                        19
# placeholder                                   2
# policy_paper                               8255
# press_release                             22283
# procurement                                  58
# promotional                                 913
# raib_report                                 436
# recruitment                                  85
# regulation                                  680
# research                                   9906
# residential_property_tribunal_decision      362
# simple_smart_answer                          31
# speech                                     6027
# statistical_data_set                        621
# statistics                                   30
# statistics_announcement                    1018
# statutory_guidance                          923
# statutory_instrument                        238
# step_by_step_nav                             40
# take_part                                    17
# tax_tribunal_decision                       765
# terms_of_reference                           28
# transaction                                 305
# transparency                               8437
# utaac_decision                              729
# welsh_language_scheme                        21
# world_news_story                           9521
# written_statement                          1493
# Length: 76, dtype: int64

# %% [markdown]
# These are the publication formats. From here: https://docs.google.com/spreadsheets/d/1AWsPFXUhJzqCBR0r0iag1UZ1bavneu8ZBABZzKFZ3XY/edit#gid=0
#
# This is for MVP. If doing this again, extract schema_name from content store and identify publications where schemea_name=publication
#
# publication: corporate report
# publication: correspondence
# publication: foi release
# publication: form
# publication: guidance
# publication: impact assessment
# publication: independant report
# publication: international treaty
# publication: map
# publication: notice
# publication: policy paper
# publication: promotional material
# publication: regulation
# publication: research and analysis
# publication: statutory guidance
# publication: transparency data
#
#     content[content['document_type']=='publications']

# %%
publications = ["corporate report", 
                "correspondence",
                "foi release",
                "form",
                "guidance",
                "impact assessment",
                "independant report",
                "international treaty",
                "map",
                "notice",
                "policy paper",
                "promotional material",
                "regulation",
                "research and analysis",
                "statutory guidance",
                "transparency data"
               ]

# %%
content.shape
# Out:
# (242861, 12)

# %%
content[(content.brexit==1) & (content['document_type'].isin(publications))].shape
# Out:
# (269, 12)

# %%
content[(content.brexit==1) & (content['document_type'].isin(publications))]
# Out:
#                                                 base_path  \
# 1034    /government/publications/eu-exit-no-deal-prepa...
# 3220    /government/publications/trading-gas-with-the-...
# 4203    /government/publications/exceeding-permit-limi...
# 5014    /government/publications/costa-amendment-lette...
# 5438    /government/publications/cmas-role-in-mergers-...
# 6536    /government/publications/using-and-trading-in-...
# 7794    /government/publications/approval-of-premises-...
# 8221    /government/publications/broadcasting-and-vide...
# 8372    /government/publications/chancellor-letter-to-...
# 8742    /government/publications/how-medicines-medical...
# 11564   /government/publications/draft-ring-fenced-bod...
# 11652   /government/publications/protecting-geographic...
# 12159   /government/publications/accounting-and-audit-...
# 13367   /government/publications/nis-regulation-eu-exi...
# 13966   /government/publications/accessing-public-sect...
# 15795   /government/publications/eu-exit-no-deal-prepa...
# 17615   /government/publications/status-of-conformity-...
# 17912   /government/publications/letter-to-the-health-...
# 18632   /government/publications/draft-notices-to-be-m...
# 19273   /government/publications/uk-participation-in-t...
# 19795   /government/publications/european-regional-dev...
# 20201   /government/publications/registration-of-veter...
# 20710   /government/publications/brexit-and-the-uk-tra...
# 21333   /government/publications/taking-horses-abroad-...
# 22385   /government/publications/eu-settlement-scheme-...
# 23164   /government/publications/mobile-roaming-if-the...
# 24130   /government/publications/list-of-approved-coun...
# 24620   /government/publications/developing-geneticall...
# 25067   /government/publications/eu-settlement-scheme-...
# 25524   /government/publications/shipping-radioactive-...
# ...                                                   ...
# 220672  /government/publications/changes-to-spc-and-pa...
# 221527  /government/publications/reliefs-from-import-d...
# 222608  /government/publications/draft-notices-to-be-m...
# 223032  /government/publications/travelling-to-the-eu-...
# 225392  /government/publications/changes-to-trade-mark...
# 225700  /government/publications/meeting-rail-safety-a...
# 225939  /government/publications/your-consumer-rights-...
# 227428  /government/publications/vitamins-and-minerals...
# 228245  /government/publications/accessing-animal-medi...
# 229044  /government/publications/producing-and-labelli...
# 229783  /government/publications/flights-to-and-from-t...
# 230401  /government/publications/existing-free-trade-a...
# 230403  /government/publications/industrial-emissions-...
# 231182  /government/publications/draft-deposit-guarant...
# 231311  /government/publications/prepare-to-import-rel...
# 234142  /government/publications/exporting-to-czech-re...
# 234291  /government/publications/adult-social-care-pro...
# 234624  /government/publications/eu-settlement-scheme-...
# 234950  /government/publications/nutrition-and-health-...
# 236233  /government/publications/commercial-road-haula...
# 236266  /government/publications/sanctions-and-anti-mo...
# 238107  /government/publications/horizon-2020-funding-...
# 238289  /government/publications/importing-animals-and...
# 238872  /government/publications/taking-your-pet-abroa...
# 238924  /government/publications/trade-bill-factsheet-...
# 239735  /government/publications/eu-exit-preparations-...
# 240289  /government/publications/cross-border-civil-an...
# 241338  /government/publications/medical-devices-and-c...
# 241517  /government/publications/letter-outlining-the-...
# 241756  /government/publications/draft-trade-repositor...
#
#                                   content_id  \
# 1034    ec7c51f8-b462-422c-85a7-2f625e598c5c
# 3220    2bc4c469-c897-45c7-acde-fd2d13c0bf64
# 4203    6a2e0886-8acb-4945-9ee8-43eaf541ca74
# 5014    6c6b6d5d-c450-4afb-8be3-ad3d57e178b9
# 5438    9f4a1967-d9b2-46c7-8b97-a132c397b4c4
# 6536    947be292-6e11-4701-b6bd-8c69fb73967d
# 7794    31e6684e-5f70-43aa-b5b6-f1a02b0c5c0d
# 8221    3cc5136a-ca14-45a5-8513-3a9dd3aa74f2
# 8372    9388ef57-2729-4782-8879-ee3516fb1a60
# 8742    fa4cccc1-7688-470a-97e7-9be00bcf2eab
# 11564   23e6a890-dabf-48b0-b35c-5a946df4a5af
# 11652   344d78b9-7ec1-4626-80fb-32530e69fbac
# 12159   ccb7bfb8-7372-43f0-82d6-2ac5c9877a4c
# 13367   42da7e7c-6854-44ab-a4d7-dc7a2785f65d
# 13966   311a7b7a-2964-45f2-8aa0-16e81252957c
# 15795   a2118377-7433-4081-a574-b2c43f119339
# 17615   6b7dddaa-93f7-4dfd-be53-e6a004df3ea6
# 17912   20563bc6-f9ba-4b74-b026-ef70012a08fe
# 18632   cddcbc76-c722-4ade-bd50-07dbd7d75290
# 19273   74de31ae-4d9c-42ed-9392-34b35a50c192
# 19795   607554d2-981d-4184-bee6-0459b75f5978
# 20201   4c554974-e684-4c86-8795-3b4fdcdd486c
# 20710   13710c01-0f2c-4fe5-b81b-f7ac5873883b
# 21333   3e39b239-340d-414d-9661-d22a231ae8cc
# 22385   c325f229-bc74-4332-8fe0-71a3d1194c40
# 23164   19ef54c2-4033-4d7b-b463-51090233a55f
# 24130   2bcd6bae-56b1-464c-a7cc-e700e8932754
# 24620   1339dbc8-5675-4350-aac4-3a24dc35a508
# 25067   c78f6f78-fc5a-4619-9739-506d7453e79e
# 25524   0467e924-391a-4c0e-81a6-16c71789c475
# ...                                      ...
# 220672  ecbcf302-c4ad-43f8-b9ab-661f198438dc
# 221527  43ca6f7c-e45d-4bcb-8f31-090d539ca9bf
# 222608  2e5deb1f-8150-448d-8829-12e8f5aa8c42
# 223032  a0ab4346-9a71-4ed9-b666-9d5fe65ddc8c
# 225392  f71f4940-b3dc-4995-ada5-5d4226e6a27a
# 225700  d5cab433-0d25-414e-8276-8d24501d515b
# 225939  49c1a6f0-68e3-414c-bb43-9f03fafd3a66
# 227428  160df39a-0987-4542-84e9-7b29f53c26fb
# 228245  5339b8b1-bef9-4d43-8085-51e4c1b184b1
# 229044  e3634cf7-ce8d-4732-ad9f-205637cddd3e
# 229783  95d15a59-2b67-4876-8b49-9482e3057a35
# 230401  f7c1991f-5842-43e7-a4d5-4be32a9b8ac5
# 230403  a115dfb1-43c7-4a07-9300-87c50187c7c1
# 231182  4cc61dfa-2ee6-4263-a4a3-5c852afc8720
# 231311  63351041-66e6-495b-a0c0-24f115f0fd3e
# 234142  5f4e061c-7631-11e4-a3cb-005056011aef
# 234291  1574fa12-4911-4835-8eb2-8f9e6b8eb8e1
# 234624  be2724ac-6ccd-497f-b9c6-27e6c57c6433
# 234950  8094dbff-202a-4da0-8fcb-4a9e0803c9b8
# 236233  30097c2d-b7e7-4909-b56f-455b815ae145
# 236266  4dca22fa-44d8-4f16-bdf4-a4e67982a726
# 238107  9a394eb8-daa0-4341-9009-e5b32f9c0148
# 238289  d12e47ab-5a35-4d12-8b1d-df75b6d0e1ea
# 238872  11e8c74a-c41c-4d6a-89f7-f3e0b74214a9
# 238924  144bd1ab-8172-48ad-bfc2-d53b71bb882a
# 239735  b81beed0-f972-4efb-8bc1-8ca7a5046e0f
# 240289  6382c7f9-a4e5-471b-83b8-b066ad204934
# 241338  26d05fb0-7db7-4913-8d75-240dcc3bdae7
# 241517  1d48d708-66e4-40bc-9cb8-16a013f95298
# 241756  5eede938-891d-41ea-8af5-ec785404a39b
#
#                                               description   document_type  \
# 1034    advice to further education and apprenticeship...        guidance
# 3220    how cross-border gas trading with the eu will ...        guidance
# 4203    holding additional radioactive materials and m...        guidance
# 5014    secretary of state steve barclay and european ...  correspondence
# 5438    role of the cma in mergers if there's 'no deal...        guidance
# 6536    how businesses dealing with fluorinated gases ...        guidance
# 7794    get approval for inspection of plant health co...            form
# 8221    how the rules for broadcasters and providers o...        guidance
# 8372    a letter from philip hammond responding to nic...  correspondence
# 8742    continuing human medicine device and clinical ...        guidance
# 11564   this publication sets out the proposed amendme...        guidance
# 11652   how producers of food products with geographic...        guidance
# 12159   how the accounting and audit sectors would be ...  correspondence
# 13367   this guidance gives information to digital ser...        guidance
# 13966   to explain how existing or potential bidders f...        guidance
# 15795   advice to higher education institutions in eng...        guidance
# 17615   this guidance covers the status of conformity ...        guidance
# 17912   the secretary of state for health and social c...  correspondence
# 18632   read drafts of the notices that hmrc will make...        guidance
# 19273   an overview of the uk’s relationship with the ...        guidance
# 19795   how current and future european regional devel...        guidance
# 20201   how the registration of veterinary medicines w...        guidance
# 20710   this guidance provides information about what ...        guidance
# 21333   how people taking horses abroad would be affec...        guidance
# 22385   information for eu citizens applying to the eu...        guidance
# 23164   how leaving the eu without a deal would affect...        guidance
# 24130   guidance on the lists of approved countries fo...        guidance
# 24620   how developing genetically modified organisms ...        guidance
# 25067   guidance for caseworkers considering applicati...        guidance
# 25524   what operators need to do to move radioactive ...        guidance
# ...                                                   ...             ...
# 220672  changes to supplementary protection certificat...        guidance
# 221527  the goods and specified uses for which they ca...        guidance
# 222608  read the draft text of notices that will be ma...        guidance
# 223032  check whether you would be affected by changes...        guidance
# 225392  changes to trade mark law in the event of no d...        guidance
# 225700  how meeting rail safety interoperability and s...        guidance
# 225939  how consumers’ rights will be protected when t...        guidance
# 227428  information about vitamins minerals and certai...        guidance
# 228245  how it systems relating to veterinary medicine...        guidance
# 229044  how the labelling of food as well as compositi...        guidance
# 229783  how air passengers and aviation businesses wou...        guidance
# 230401  how we would ensure continuity for the uk’s ex...        guidance
# 230403  how standards for emissions from industry affe...        guidance
# 231182  draft statutory instrument which will make ame...        guidance
# 231311  what importers of relevant nuclear material wi...        guidance
# 234142  a guide for british businesses who are interes...        guidance
# 234291  letter to adult social care providers giving a...  correspondence
# 234624  this notice only applies to those contacted ab...        guidance
# 234950  register of nutrition and health claims that m...        guidance
# 236233  how uk haulage companies drivers and freight s...        guidance
# 236266  this document sets out the government’s intend...        guidance
# 238107  if there is ‘no deal’ the government has taken...        guidance
# 238289  how importing animals animal products and high...        guidance
# 238872  how taking your pet to the eu would be affecte...        guidance
# 238924  the trade bill will ensure the uk is ready for...        guidance
# 239735  letters requesting and confirming a ministeria...  correspondence
# 240289  guidance for legal professionals on applicable...        guidance
# 241338  letter from matt hancock to suppliers of medic...  correspondence
# 241517  hmrc letter to traders explaining changes to b...  correspondence
# 241756  draft statutory instrument which will make ame...        guidance
#
#                    first_published_at locale  \
# 1034    2019-01-31T13:01:00.000+00:00     en
# 3220    2018-10-12T12:00:00.000+00:00     en
# 4203    2019-04-01T15:36:00.000+00:00     en
# 5014    2019-03-05T13:33:00.000+00:00     en
# 5438    2018-10-30T12:53:00.000+00:00     en
# 6536    2018-09-13T12:00:00.000+00:00     en
# 7794    2018-12-19T12:00:00.000+00:00     en
# 8221    2018-09-13T12:00:00.000+00:00     en
# 8372    2018-08-23T14:00:12.000+00:00     en
# 8742    2018-08-23T11:00:00.000+00:00     en
# 11564   2018-10-22T15:01:44.000+00:00     en
# 11652   2018-09-24T14:30:00.000+00:00     en
# 12159   2019-02-21T16:56:00.000+00:00     en
# 13367   2018-12-21T12:54:00.000+00:00     en
# 13966   2018-09-13T12:00:00.000+00:00     en
# 15795   2019-01-31T13:00:00.000+00:00     en
# 17615   2019-03-19T10:00:00.000+00:00     en
# 17912   2018-08-23T11:02:00.000+00:00     en
# 18632   2019-03-08T14:43:00.000+00:00     en
# 19273   2019-03-08T11:59:22.000+00:00     en
# 19795   2018-09-13T12:00:00.000+00:00     en
# 20201   2018-09-24T14:30:00.000+00:00     en
# 20710   2018-10-12T11:17:00.000+00:00     en
# 21333   2018-10-12T12:00:00.000+00:00     en
# 22385   2018-08-30T08:00:00.000+00:00     en
# 23164   2018-09-13T12:00:00.000+00:00     en
# 24130   2019-03-11T16:15:00.000+00:00     en
# 24620   2018-08-23T11:00:00.000+00:00     en
# 25067   2018-08-28T10:50:00.000+00:00     en
# 25524   2019-03-25T16:29:00.000+00:00     en
# ...                               ...    ...
# 220672  2019-03-08T12:00:00.000+00:00     en
# 221527  2019-03-13T07:00:00.000+00:00     en
# 222608  2018-11-30T16:04:00.000+00:00     en
# 223032  2018-09-13T12:00:00.000+00:00     en
# 225392  2019-03-01T10:24:00.000+00:00     en
# 225700  2018-10-12T12:00:00.000+00:00     en
# 225939  2019-01-08T16:37:00.000+00:00     en
# 227428  2019-03-26T16:57:00.000+00:00     en
# 228245  2018-09-24T14:30:00.000+00:00     en
# 229044  2018-09-24T14:30:00.000+00:00     en
# 229783  2018-09-24T14:30:00.000+00:00     en
# 230401  2018-10-12T12:00:00.000+00:00     en
# 230403  2018-09-13T12:00:00.000+00:00     en
# 231182  2018-08-15T13:26:53.000+00:00     en
# 231311  2019-01-31T14:45:00.000+00:00     en
# 234142  2015-01-15T00:00:00.000+00:00     en
# 234291  2019-03-14T14:02:58.000+00:00     en
# 234624  2018-12-21T15:46:16.000+00:00     en
# 234950  2019-03-26T16:52:25.000+00:00     en
# 236233  2018-09-24T14:30:00.000+00:00     en
# 236266  2018-05-01T12:34:52.000+00:00     en
# 238107  2018-08-23T11:00:00.000+00:00     en
# 238289  2018-09-24T14:30:00.000+00:00     en
# 238872  2018-09-24T14:30:00.000+00:00     en
# 238924  2018-12-14T16:33:50.000+00:00     en
# 239735  2018-01-19T10:00:03.000+00:00     en
# 240289  2019-03-29T17:21:00.000+00:00     en
# 241338  2018-10-23T10:30:03.000+00:00     en
# 241517  2019-01-18T10:57:00.000+00:00     en
# 241756  2018-10-05T15:19:00.000+00:00     en
#
#                           primary_publishing_organisation publishing_app  \
# 1034                             Department for Education      whitehall
# 3220    Department for Business, Energy & Industrial S...      whitehall
# 4203                                   Environment Agency      whitehall
# 5014            Department for Exiting the European Union      whitehall
# 5438                    Competition and Markets Authority      whitehall
# 6536     Department for Environment, Food & Rural Affairs      whitehall
# 7794     Department for Environment, Food & Rural Affairs      whitehall
# 8221       Department for Digital, Culture, Media & Sport      whitehall
# 8372                                          HM Treasury      whitehall
# 8742                 Department of Health and Social Care      whitehall
# 11564                                         HM Treasury      whitehall
# 11652    Department for Environment, Food & Rural Affairs      whitehall
# 12159   Department for Business, Energy & Industrial S...      whitehall
# 13367      Department for Digital, Culture, Media & Sport      whitehall
# 13966                                      Cabinet Office      whitehall
# 15795                            Department for Education      whitehall
# 17615   Department for Business, Energy & Industrial S...      whitehall
# 17912                Department of Health and Social Care      whitehall
# 18632                                HM Revenue & Customs      whitehall
# 19273   Department for Business, Energy & Industrial S...      whitehall
# 19795   Department for Business, Energy & Industrial S...      whitehall
# 20201    Department for Environment, Food & Rural Affairs      whitehall
# 20710                       Foreign & Commonwealth Office      whitehall
# 21333    Department for Environment, Food & Rural Affairs      whitehall
# 22385                                         Home Office      whitehall
# 23164      Department for Digital, Culture, Media & Sport      whitehall
# 24130   Medicines and Healthcare products Regulatory A...      whitehall
# 24620    Department for Environment, Food & Rural Affairs      whitehall
# 25067                                         Home Office      whitehall
# 25524   Department for Business, Energy & Industrial S...      whitehall
# ...                                                   ...            ...
# 220672                       Intellectual Property Office      whitehall
# 221527                                        HM Treasury      whitehall
# 222608                               HM Revenue & Customs      whitehall
# 223032                                        Home Office      whitehall
# 225392                       Intellectual Property Office      whitehall
# 225700                           Department for Transport      whitehall
# 225939  Department for Business, Energy & Industrial S...      whitehall
# 227428               Department of Health and Social Care      whitehall
# 228245   Department for Environment, Food & Rural Affairs      whitehall
# 229044   Department for Environment, Food & Rural Affairs      whitehall
# 229783                           Department for Transport      whitehall
# 230401                 Department for International Trade      whitehall
# 230403   Department for Environment, Food & Rural Affairs      whitehall
# 231182                                        HM Treasury      whitehall
# 231311  Department for Business, Energy & Industrial S...      whitehall
# 234142                 Department for International Trade      whitehall
# 234291               Department of Health and Social Care      whitehall
# 234624                                        Home Office      whitehall
# 234950               Department of Health and Social Care      whitehall
# 236233                           Department for Transport      whitehall
# 236266                      Foreign & Commonwealth Office      whitehall
# 238107  Department for Business, Energy & Industrial S...      whitehall
# 238289   Department for Environment, Food & Rural Affairs      whitehall
# 238872   Department for Environment, Food & Rural Affairs      whitehall
# 238924                 Department for International Trade      whitehall
# 239735   Department for Environment, Food & Rural Affairs      whitehall
# 240289                                Ministry of Justice      whitehall
# 241338               Department of Health and Social Care      whitehall
# 241517                               HM Revenue & Customs      whitehall
# 241756                                        HM Treasury      whitehall
#
#                                                     title  \
# 1034    eu exit: no deal preparations for further educ...
# 3220    trading gas with the eu if there's no brexit deal
# 4203    exceeding permit limits when you obtain additi...
# 5014    costa amendment: correspondence with the eu in...
# 5438               merger cases if there's no brexit deal
# 6536    using and trading in fluorinated gases and ozo...
# 7794    approval of premises as place of first arrival...
# 8221    broadcasting and video on demand if there’s no...
# 8372    chancellor letter to chair of treasury committ...
# 8742    how medicines medical devices and clinical tri...
# 11564   draft ring-fenced bodies (amendment) (eu exit)...
# 11652   protecting geographical food and drink names i...
# 12159   accounting and audit if there’s no brexit deal...
# 13367   nis regulation: eu exit guidance for digital s...
# 13966   accessing public sector contracts if there’s n...
# 15795   eu exit: no deal preparations for higher educa...
# 17615   status of conformity assessment bodies after b...
# 17912   letter to the health and care sector: preparat...
# 18632   draft notices to be made in relation to the am...
# 19273   uk participation in the research fund for coal...
# 19795   european regional development funding (erdf) i...
# 20201   registration of veterinary medicines if there’...
# 20710              trading in rough diamonds after brexit
# 21333      taking horses abroad if there’s no brexit deal
# 22385   eu settlement scheme: view and prove your righ...
# 23164            mobile roaming if there’s no brexit deal
# 24130   list of approved countries for authorised huma...
# 24620   developing genetically modified organisms (gmo...
# 25067            eu settlement scheme caseworker guidance
# 25524   shipping radioactive sources between the uk an...
# ...                                                   ...
# 220672  changes to spc and patent law if uk leaves the...
# 221527  authorised use: reliefs from import duty on go...
# 222608  draft notices to be made under the customs (sp...
# 223032  travelling to the eu with a uk passport if the...
# 225392  changes to trade mark law if the uk leaves the...
# 225700  meeting rail safety and standards if there's n...
# 225939                  your consumer rights after brexit
# 227428  vitamins and minerals in foods if there’s no e...
# 228245  accessing animal medicine it systems if there'...
# 229044  producing and labelling food if there's no bre...
# 229783  flights to and from the uk if there’s no brexi...
# 230401  existing free trade agreements if there's no b...
# 230403  industrial emissions standards (‘best availabl...
# 231182  draft deposit guarantee scheme and miscellaneo...
# 231311  prepare to import ‘relevant’ nuclear materials...
# 234142                        exporting to czech republic
# 234291  adult social care providers: eu exit planning ...
# 234624   eu settlement scheme: privacy information notice
# 234950  nutrition and health claims on foods if there’...
# 236233  commercial road haulage in the eu if there’s n...
# 236266  sanctions and anti-money laundering bill: exce...
# 238107     horizon 2020 funding if there's no brexit deal
# 238289  importing animals and animal products if there...
# 238872   taking your pet abroad if there's no brexit deal
# 238924  trade bill factsheet: providing continuity and...
# 239735        eu exit preparations: ministerial direction
# 240289  cross-border civil and commercial legal cases ...
# 241338           medical devices and clinical consumables
# 241517  letter outlining the effect of 'no deal' brexi...
# 241756  draft trade repositories (amendment and transi...
#
#                                                      body  \
# 1034    preparations that organisations and businesses...
# 3220    if the uk leaves the eu on 31 october 2019 wit...
# 4203    eu exit may result in restricted supplies of r...
# 5014    in his letter the secretary of state for exiti...
# 5438    how the cma will handle mergers in a ‘no deal’...
# 6536    if the uk leaves the eu in march 2019 without ...
# 7794    read the guide on approval and operation of pl...
# 8221    if the uk leaves the eu with no deal find out ...
# 8372    the chancellor of the exchequer philip hammond...
# 8742    if the uk leaves the eu ion 12 april 2019 with...
# 11564   this si will make amendments to uk secondary l...
# 11652   if the uk leaves the eu in march 2019 without ...
# 12159   the government and the financial reporting cou...
# 13367   the nis directive will continue to apply in th...
# 13966   if the uk leaves the eu in march 2019 with no ...
# 15795   preparations that higher education organisatio...
# 17615   if the uk leaves the eu without a deal find ou...
# 17912   the secretary of state for health and social c...
# 18632   this document provides drafts of notices that ...
# 19273   the eu research fund for coal and steel ( rfcs...
# 19795   if the uk leaves the eu on 31 october 2019 wit...
# 20201   if the uk leaves the eu without a deal find ou...
# 20710   leaving the eu will have implications on the u...
# 21333   if the uk leaves the eu in march 2019 without ...
# 22385   this guidance is for eu citizens applying to t...
# 23164   find out how businesses and consumers would be...
# 24130   leaving the eu with a deal remains the governm...
# 24620   if the uk leaves the eu in march 2019 without ...
# 25067   this guidance tells caseworkers how to conside...
# 25524   if the uk leaves the eu without a deal some of...
# ...                                                   ...
# 220672  if the uk leaves the eu without a deal there w...
# 221527  this document lists the eligible goods and des...
# 222608  this document provides drafts of the notices t...
# 223032  the entry requirements for british passport ho...
# 225392  this relates to european union trade marks onl...
# 225700  if the uk leaves the eu on 31 october 2019 wit...
# 225939  find out how brexit will affect your consumer ...
# 227428  this uk register specifies which vitamins and ...
# 228245  if the uk leaves the eu without a deal find ou...
# 229044  if the uk leaves the eu in march 2019 without ...
# 229783  if the uk leaves the eu in april 2019 without ...
# 230401  if the uk leaves the eu in march 2019 without ...
# 230403  if the uk leaves the eu without a deal find ou...
# 231182  this si will make amendments to retained eu la...
# 231311  if the uk leaves the eu without a deal busines...
# 234142  a detailed guide on doing business in and with...
# 234291  the letter describes what the government is do...
# 234624  personal information supplied or collected for...
# 234950  the uk nutrition and health claims register se...
# 236233  if the uk leaves the eu in march 2019 without ...
# 236266  the sanctions and anti money laundering bill i...
# 238107  find out how the government plans to support u...
# 238289  if the uk leaves the eu in march 2019 without ...
# 238872  if the uk leaves the eu in march 2019 without ...
# 238924  the trade bill was introduced into the house o...
# 239735  the first letter is from the permanent secreta...
# 240289  this guidance is provided for the information ...
# 241338  the secretary of state for health and social c...
# 241517  hmrc has written to businesses across the uk t...
# 241756  this si will make amendments to retained eu la...
#
#                                             combined_text  brexit
# 1034    eu exit: no deal preparations for further educ...       1
# 3220    trading gas with the eu if there's no brexit d...       1
# 4203    exceeding permit limits when you obtain additi...       1
# 5014    costa amendment: correspondence with the eu in...       1
# 5438    merger cases if there's no brexit deal role of...       1
# 6536    using and trading in fluorinated gases and ozo...       1
# 7794    approval of premises as place of first arrival...       1
# 8221    broadcasting and video on demand if there’s no...       1
# 8372    chancellor letter to chair of treasury committ...       1
# 8742    how medicines medical devices and clinical tri...       1
# 11564   draft ring-fenced bodies (amendment) (eu exit)...       1
# 11652   protecting geographical food and drink names i...       1
# 12159   accounting and audit if there’s no brexit deal...       1
# 13367   nis regulation: eu exit guidance for digital s...       1
# 13966   accessing public sector contracts if there’s n...       1
# 15795   eu exit: no deal preparations for higher educa...       1
# 17615   status of conformity assessment bodies after b...       1
# 17912   letter to the health and care sector: preparat...       1
# 18632   draft notices to be made in relation to the am...       1
# 19273   uk participation in the research fund for coal...       1
# 19795   european regional development funding (erdf) i...       1
# 20201   registration of veterinary medicines if there’...       1
# 20710   trading in rough diamonds after brexit this gu...       1
# 21333   taking horses abroad if there’s no brexit deal...       1
# 22385   eu settlement scheme: view and prove your righ...       1
# 23164   mobile roaming if there’s no brexit deal how l...       1
# 24130   list of approved countries for authorised huma...       1
# 24620   developing genetically modified organisms (gmo...       1
# 25067   eu settlement scheme caseworker guidance guida...       1
# 25524   shipping radioactive sources between the uk an...       1
# ...                                                   ...     ...
# 220672  changes to spc and patent law if uk leaves the...       1
# 221527  authorised use: reliefs from import duty on go...       1
# 222608  draft notices to be made under the customs (sp...       1
# 223032  travelling to the eu with a uk passport if the...       1
# 225392  changes to trade mark law if the uk leaves the...       1
# 225700  meeting rail safety and standards if there's n...       1
# 225939  your consumer rights after brexit how consumer...       1
# 227428  vitamins and minerals in foods if there’s no e...       1
# 228245  accessing animal medicine it systems if there'...       1
# 229044  producing and labelling food if there's no bre...       1
# 229783  flights to and from the uk if there’s no brexi...       1
# 230401  existing free trade agreements if there's no b...       1
# 230403  industrial emissions standards (‘best availabl...       1
# 231182  draft deposit guarantee scheme and miscellaneo...       1
# 231311  prepare to import ‘relevant’ nuclear materials...       1
# 234142  exporting to czech republic a guide for britis...       1
# 234291  adult social care providers: eu exit planning ...       1
# 234624  eu settlement scheme: privacy information noti...       1
# 234950  nutrition and health claims on foods if there’...       1
# 236233  commercial road haulage in the eu if there’s n...       1
# 236266  sanctions and anti-money laundering bill: exce...       1
# 238107  horizon 2020 funding if there's no brexit deal...       1
# 238289  importing animals and animal products if there...       1
# 238872  taking your pet abroad if there's no brexit de...       1
# 238924  trade bill factsheet: providing continuity and...       1
# 239735  eu exit preparations: ministerial direction le...       1
# 240289  cross-border civil and commercial legal cases ...       1
# 241338  medical devices and clinical consumables lette...       1
# 241517  letter outlining the effect of 'no deal' brexi...       1
# 241756  draft trade repositories (amendment and transi...       1
#
# [269 rows x 12 columns]

# %%
publications_and_guidance = content[content['document_type'].isin(publications)]

# %%
embedded_sentences_brexit_publications = embedded_sentences[(content.brexit==1) & (content['document_type'].isin(publications))]

# %% [markdown]
# ## Get similarity scores, brexit content by all GOV.UK content

# %%
def get_top_20_links(D_chunk, start):
    """return only the top 20 (including self) related link indices and distance metric values
    according to distance metric"""
    top_k_indices = np.argpartition(D_chunk, range(20))[:, :20]

    return top_k_indices, D_chunk[:, top_k_indices]

brexit_generator = pairwise_distances_chunked(
    X=embedded_sentences_brexit_publications,
    Y=embedded_sentences,
    reduce_func=get_top_20_links,
    working_memory=0,
    metric='cosine',
    n_jobs=-1)

# %%
brexit_url = []
close_content_urls = []
urls = pd.DataFrame(columns=['brexit_url', 'close_content_urls', 'cosine_sims'])
for i, (indices, values) in enumerate(tqdm_notebook(brexit_generator)):

    brexit_url = content.iat[indices[0][0],
                                     0]  #basepath is first column
    close_content_urls = [content.iat[i, 0] for i in indices[0]]
    #     cosine_sims = pd.Series(values)
    i_urls = pd.DataFrame({
        'brexit_url': brexit_url,
        'close_content_urls': close_content_urls,
        'cosine_sims': values.reshape(20)
    })
    urls = urls.append(i_urls, ignore_index=True)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# /Users/ellieking/.pyenv/versions/3.6.4/envs/content-similarity-3.6.4/lib/python3.6/site-packages/sklearn/utils/__init__.py:603: UserWarning: Could not adhere to working_memory config. Currently 0MiB, 2MiB required.
#   (working_memory, np.ceil(row_bytes * 2 ** -20)))

# %% [markdown]
# ### Save out list

# %%
urls.to_csv("brexit_publications_potential_dupes.csv", index=False)
