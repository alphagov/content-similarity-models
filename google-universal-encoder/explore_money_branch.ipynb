# %% [markdown]
# # Explore the use of cosine similarity measures on the money branch to improve its structure

# %% [markdown]
# # Context

# %% [markdown]
# This notebook is for identifying areas of the taxonomy where content is not well sorted and may require further curation. We're focusing on the money branch.
#
# We're looking to explore and flag:
#
# 1. Content in the wrong place (its semantically different to other items in that taxon)
# 1. Odd taxon structure (content diversity, taxon size and depth)
# 1. Taxons that need splitting (clusters of closely-related content exist within a taxon)
# 1. Taxons that need merging (there's a large overlap in content tagging between branches)

# %% [markdown]
# # Prepare workspace

# %% [markdown]
# Assuming for now that your working directory is at `/content-similarity-models/google-universal-encoder`

# %%
# !pwd
# Out:
# /Users/matthewdray/Documents/content-similarity-models/google-universal-encoder

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import pairwise_distances, pairwise_distances_chunked

import altair as alt
from altair import datum

# %% [markdown]
# # Read and prepare data

# %%
## Embedded sentences

# %%
embedded_sentences = np.load('../data/embedded_sentences2019-02-11.npy')

# %% [markdown]
# ## Labelled data
# We may also need to read the `labelled.csv` data to create some objects that will be used later. The labelled data is one of the inputs to the `get_homogeneity_scores_taxon.py script` that produces `taxon_homogeneity_df.csv`.

# %%
labelled = pd.read_csv(
    '../data/2019-02-11/labelled.csv.gz',
    compression='gzip',
    low_memory=False
)

# %%
labelled
# Out:
#                                                 base_path  \
# 0       /government/publications/list-of-psychologists...
# 1       /government/news/charity-commission-names-furt...
# 2       /government/publications/trust-and-confidence-...
# 3       /government/speeches/william-shawcross-speech-...
# 4       /government/statistics/crime-statistics-focus-...
# ...                                                   ...
# 305698   /government/statistics/hydrocarbon-oils-bulletin
# 305699  /government/news/uk-government-agriculture-bil...
# 305700                             /vat-building-new-home
# 305701  /government/publications/ms-no82019-agreement-...
# 305702            /capital-gains-tax-personal-possessions
#
#                                   content_id  \
# 0       04a0cc0d-0b9f-45ad-bf57-7c54cbab9df9
# 1       5fa49c52-7631-11e4-a3cb-005056011aef
# 2       d0341424-12a1-4b4c-9045-2e74ba17f2d5
# 3       9245dfca-4210-41d9-9ffd-7fcc35dc1642
# 4       5fec046a-7631-11e4-a3cb-005056011aef
# ...                                      ...
# 305698  5bb58f44-9ebd-42ff-87ad-e4e16b40468b
# 305699  ef674b76-5d8d-4d18-bf0f-8ed651a0637b
# 305700  7757ba54-161a-479a-96a2-a50420929f1a
# 305701  365c01a0-7f3f-4218-acfb-3d1234956a4b
# 305702  43446591-3f95-443d-9fb2-56761a93106b
#
#                                               description  \
# 0       list of english speaking psychologists and psy...
# 1           regulator increases transparency of its work.
# 2       independent research into trust and confidence...
# 3       william shawcross asks charities to pull toget...
# 4       crime statistics from the crime survey for eng...
# ...                                                   ...
# 305698  monthly statistics on duty receipts and cleara...
# 305699  agriculture is devolved and will remain devolv...
# 305700  vat refunds on building new homes and conversi...
# 305701              presented to parliament february 2019
# 305702  what personal possessions (chattels) you need ...
#
#                document_type             first_published_at locale  \
# 0                   guidance  2017-07-21T16:42:00.000+00:00     en
# 1              press_release  2014-06-04T23:00:00.000+00:00     en
# 2                   research  2015-06-25T07:00:00.000+00:00     en
# 3                     speech  2016-02-29T12:39:07.000+00:00     en
# 4        national_statistics  2015-03-26T09:30:00.000+00:00     en
# ...                      ...                            ...    ...
# 305698   national_statistics  2016-02-19T09:30:00.000+00:00     en
# 305699            news_story  2018-09-13T15:58:00.000+00:00     en
# 305700                 guide  2012-09-13T12:32:40.000+00:00     en
# 305701  international_treaty  2019-02-08T14:00:12.000+00:00     en
# 305702                 guide  2014-10-13T12:00:18.000+00:00     en
#
#                       primary_publishing_organisation publishing_app  \
# 0                       Foreign & Commonwealth Office      whitehall
# 1                              The Charity Commission      whitehall
# 2                              The Charity Commission      whitehall
# 3                              The Charity Commission      whitehall
# 4                      Office for National Statistics      whitehall
# ...                                               ...            ...
# 305698                           HM Revenue & Customs      whitehall
# 305699  Office of the Secretary of State for Scotland      whitehall
# 305700                     Government Digital Service      publisher
# 305701                  Foreign & Commonwealth Office      whitehall
# 305702                     Government Digital Service      publisher
#
#                                                     title  \
# 0       chile - list of psychologists and psychiatrist...
# 1       charity commission names further charities und...
# 2       trust and confidence in the charity commission...
# 3       william shawcross speech at commission’s publi...
# 4       public perceptions of crime and the police and...
# ...                                                   ...
# 305698                          hydrocarbon oils bulletin
# 305699  uk government agriculture bill - scotland myth...
# 305700                        building a new home and vat
# 305701  [ms no.8/2019] agreement to promote compliance...
# 305702          capital gains tax on personal possessions
#
#                                                      body  \
# 0       prepared by british embassy/consulate santiago...
# 1       the charity commission has today named further...
# 2       the charity commission commissioned populus to...
# 3       good morning and thank you for joining us here...
# 4       official statistics are produced impartially a...
# ...                                                   ...
# 305698  the hydrocarbon oils bulletin contains statist...
# 305699  the uk government’s agriculture bill was intro...
# 305700  you can apply for a vat refund on building mat...
# 305701  published title: agreement to promote complian...
# 305702  what you pay it on you may have to pay capital...
#
#                                             combined_text  \
# 0       chile - list of psychologists and psychiatrist...
# 1       charity commission names further charities und...
# 2       trust and confidence in the charity commission...
# 3       william shawcross speech at commission’s publi...
# 4       public perceptions of crime and the police and...
# ...                                                   ...
# 305698  hydrocarbon oils bulletin monthly statistics o...
# 305699  uk government agriculture bill - scotland myth...
# 305700  building a new home and vat vat refunds on bui...
# 305701  [ms no.8/2019] agreement to promote compliance...
# 305702  capital gains tax on personal possessions what...
#
#                                     taxon_id  \
# 0       668cd623-c7a8-4159-9575-90caac36d4b4
# 1       668cd623-c7a8-4159-9575-90caac36d4b4
# 2       668cd623-c7a8-4159-9575-90caac36d4b4
# 3       668cd623-c7a8-4159-9575-90caac36d4b4
# 4       668cd623-c7a8-4159-9575-90caac36d4b4
# ...                                      ...
# 305698  efa6099d-c5a8-4adc-83b7-f149b0d8d6ee
# 305699  2368b8b1-9405-4e66-b396-a5d54b777a0a
# 305700  373e6e1c-d73f-41a7-ac8c-0da991abbedb
# 305701  66acfe61-6c51-4cd9-90e0-34e47358020c
# 305702  51522bef-3147-4d85-a4e9-ad3d94743183
#
#                                           taxon_base_path  \
# 0              /society-and-culture/community-and-society
# 1              /society-and-culture/community-and-society
# 2              /society-and-culture/community-and-society
# 3              /society-and-culture/community-and-society
# 4              /society-and-culture/community-and-society
# ...                                                   ...
# 305698  /money/business-tax-fuel-duty-payments-and-rel...
# 305699          /environment/farming-food-grants-payments
# 305700  /money/business-tax-vat-reclaiming-vat-on-a-ne...
# 305701                       /environment/fishing-vessels
# 305702  /money/personal-tax-capital-gains-tax-personal...
#
#                                   taxon_name          level1taxon  \
# 0                      Community and society  Society and culture
# 1                      Community and society  Society and culture
# 2                      Community and society  Society and culture
# 3                      Community and society  Society and culture
# 4                      Community and society  Society and culture
# ...                                      ...                  ...
# 305698      Payments and reliefs (Fuel duty)                Money
# 305699  Farming and food grants and payments          Environment
# 305700          Reclaiming VAT on a new home                Money
# 305701                       Fishing vessels          Environment
# 305702                  Personal possessions                Money
#
#                                       level2taxon  \
# 0                           Community and society
# 1                           Community and society
# 2                           Community and society
# 3                           Community and society
# 4                           Community and society
# ...                                           ...
# 305698                               Business tax
# 305699                           Food and farming
# 305700                               Business tax
# 305701  Commercial fishing, fisheries and vessels
# 305702                               Personal tax
#
#                                  level3taxon  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 305698                             Fuel Duty
# 305699  Farming and food grants and payments
# 305700                                   VAT
# 305701                       Fishing vessels
# 305702                     Capital Gains Tax
#
#                              level4taxon level5taxon
# 0                                    NaN         NaN
# 1                                    NaN         NaN
# 2                                    NaN         NaN
# 3                                    NaN         NaN
# 4                                    NaN         NaN
# ...                                  ...         ...
# 305698  Payments and reliefs (Fuel duty)         NaN
# 305699                               NaN         NaN
# 305700      Reclaiming VAT on a new home         NaN
# 305701                               NaN         NaN
# 305702              Personal possessions         NaN
#
# [305703 rows x 19 columns]

# %% [markdown]
# Prepare objects for later visualisation

# %%
taxon_id_to_base_path = dict(zip(labelled['taxon_id'], labelled['taxon_base_path']))

#taxon_id_to_level = dict(zip(labelled['taxon_id'], labelled['level']))

taxon_id_to_level1 = dict(zip(labelled['taxon_id'], labelled['level1taxon']))

# %%
taxons = labelled['taxon_id'].unique()

# %% [markdown]
# ## Branch homogeneity
# Read the homogeneity data, which is a Pandas data frame output from the `get_homogeneity_scores_taxon.py` script.

# %%
taxon_homogeneity_df = pd.read_csv("../data/taxon_homogeneity_df.csv")

# %%
taxon_homogeneity_df.shape
# Out:
# (1265, 9)

# %%
taxon_homogeneity_df.head()
# Out:
#    Unnamed: 0                              taxon_id  taxon_size  \
# 0           0  668cd623-c7a8-4159-9575-90caac36d4b4        5166
# 1         246  f9e476ef-654d-41ec-97d9-2b6842d4361d         786
# 2          48  495afdb6-47be-4df1-8b38-91c8adb1eefc        8136
# 3         833  fc5f468f-a3ba-4fde-9c1d-ed2dd17cfd82          31
# 4          18  b29cf14b-54c6-402c-a9f0-77218602d1af        2333
#
#    mean_cosine_score                                    taxon_base_path  \
# 0           0.595490         /society-and-culture/community-and-society
# 1           0.589025            /society-and-culture/sports-and-leisure
# 2           0.571510                             /business-and-industry
# 3           0.571205  /housing-local-and-community/housing-local-ser...
# 4           0.569644              /society-and-culture/arts-and-culture
#
#    taxon_level                   level1taxon  fewer_than_or_equal_5items  \
# 0            2           Society and culture                           0
# 1            2           Society and culture                           0
# 2            1         Business and industry                           0
# 3            3  Housing, local and community                           0
# 4            2           Society and culture                           0
#
#    more_than_0_5_diversity
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1

# %% [markdown]
# # Explore flagging

# %% [markdown]
# ## 1. Odd taxon structure

# %%
numcols = 6  # specify the number of columns you want
level1taxons = taxon_homogeneity_df['level1taxon'].unique() 


money = taxon_homogeneity_df[taxon_homogeneity_df.level1taxon == 'Money'].copy()

total_size = money['taxon_size'].sum().astype(str)

money_plot = alt.Chart(money).mark_circle(size=60).encode(
    alt.X(
        'taxon_size:Q',
        scale=alt.Scale(type='log', domain=(1, 10000)),
        axis=alt.Axis(grid=False, title='log(topic_size)')
    ),
    alt.Y(
        'mean_cosine_score:Q',
        scale=alt.Scale(domain=(0, 0.6)),
        axis=alt.Axis(grid=False, title='content diversity score')
    ), 
    #color='taxon_level:N',
    color=alt.Color('taxon_level:N', scale=alt.Scale(scheme='magma')),
    opacity=alt.value(0.8), 
    tooltip=['taxon_base_path']
).properties(
        title='Money' + ", " + total_size).interactive()

# %%
money_plot.save('money.html', scale_factor=2.0)

# %% [markdown]
# ## 2. Content in the wrong place
# Content may have been tagged in the wrong place. How can we identify this? One idea is to look at the cosine similarity between each content item and all the others within a taxon and then inspect the ones with scores that are above a certain threshold (i.e. they're semantically different to everything else).

# %% [markdown]
# ### Example: 'business tax' taxon

# %% [markdown]
# Store the taxon ID as a variable.

# %%
btax_id = '28262ae3-599c-4259-ae30-3c83a5ec02a1'

# %% [markdown]
# Filter the embedded sentences (a numpy array) where it matches the business tax taxon ID. Indices for `embedded sentences` and `labelled` are the same, so `labelled` can be used to help filter.

# %%
btax_embedded = embedded_sentences[labelled['taxon_id'] == btax_id]

# %% [markdown]
# Get the cosine similarity for all content item pairs in the taxon, convert to a Pandas data frame and then get the mean distances for each content item.

# %%
btax_dist = pairwise_distances(
    btax_embedded, 
    metric = 'cosine', 
    n_jobs = -1
)

# %%
btax_dist_df = pd.DataFrame(btax_dist)

# %%
btax_dist_df['mean'] = btax_dist.mean(axis = 1)

# %%
btax_dist_df
# Out:
#                 0             1         2         3         4         5  \
# 0    1.192093e-07  5.811087e-01  0.363355  0.395613  0.621481  0.643409
# 1    5.811087e-01  1.788139e-07  0.654736  0.576303  0.530271  0.626652
# 2    3.633550e-01  6.547358e-01  0.000000  0.426611  0.544326  0.555158
# 3    3.956128e-01  5.763029e-01  0.426611  0.000000  0.561196  0.589584
# 4    6.214815e-01  5.302707e-01  0.544326  0.561196  0.000000  0.402271
# ..            ...           ...       ...       ...       ...       ...
# 517  2.377652e-01  6.557679e-01  0.225597  0.411198  0.568614  0.608365
# 518  3.217012e-01  6.239149e-01  0.265516  0.428849  0.582047  0.475288
# 519  4.654763e-01  5.118585e-01  0.579925  0.496626  0.439734  0.399085
# 520  2.999914e-01  4.285663e-01  0.312676  0.362502  0.363483  0.449534
# 521  1.957843e-01  5.778310e-01  0.238606  0.414494  0.607769  0.633385
#
#             6         7         8         9  ...       513       514  \
# 0    0.289677  0.530680  0.207134  0.350927  ...  0.585443  0.505209
# 1    0.597192  0.427653  0.501061  0.444977  ...  0.646549  0.560747
# 2    0.253399  0.467847  0.262523  0.498422  ...  0.680668  0.598263
# 3    0.290253  0.435382  0.441065  0.483954  ...  0.723931  0.557843
# 4    0.556397  0.424755  0.601762  0.533905  ...  0.627540  0.514643
# ..        ...       ...       ...       ...  ...       ...       ...
# 517  0.309599  0.540137  0.215301  0.463708  ...  0.757355  0.585006
# 518  0.314286  0.372984  0.299106  0.385228  ...  0.624242  0.515264
# 519  0.474104  0.476754  0.528337  0.332032  ...  0.618840  0.338750
# 520  0.263140  0.407424  0.238127  0.388419  ...  0.630352  0.425609
# 521  0.258725  0.522327  0.145803  0.399864  ...  0.708675  0.571204
#
#           515       516       517       518           519       520  \
# 0    0.217435  0.395614  0.237765  0.321701  4.654763e-01  0.299991
# 1    0.697612  0.502061  0.655768  0.623915  5.118585e-01  0.428566
# 2    0.327363  0.497435  0.225597  0.265516  5.799253e-01  0.312676
# 3    0.340588  0.306367  0.411198  0.428849  4.966263e-01  0.362502
# 4    0.752991  0.367417  0.568614  0.582047  4.397339e-01  0.363483
# ..        ...       ...       ...       ...           ...       ...
# 517  0.277057  0.431950  0.000000  0.328338  5.502497e-01  0.331572
# 518  0.385099  0.360002  0.328338  0.000000  4.574981e-01  0.328929
# 519  0.591610  0.401148  0.550250  0.457498  5.960464e-08  0.364444
# 520  0.366184  0.259800  0.331572  0.328929  3.644440e-01  0.000000
# 521  0.207748  0.407244  0.167475  0.272134  5.100868e-01  0.265870
#
#               521      mean
# 0    1.957843e-01  0.450615
# 1    5.778310e-01  0.580138
# 2    2.386062e-01  0.438918
# 3    4.144944e-01  0.443872
# 4    6.077694e-01  0.555981
# ..            ...       ...
# 517  1.674750e-01  0.445535
# 518  2.721338e-01  0.414610
# 519  5.100868e-01  0.483382
# 520  2.658705e-01  0.419567
# 521  3.576279e-07  0.434264
#
# [522 rows x 523 columns]

# %% [markdown]
# How many content items (rows) have a larger mean distance than the overall mean?

# %%
btax_dist_df[btax_dist_df['mean'] > btax_dist.mean()].shape
# Out:
# (212, 523)

# %% [markdown]
# Now we can use this information to filter the data frame of labelled content items (`labelled`), leaving us with a data frame of the problem content.
#
# We can start by filtering the `labelled` data so we have only the content items that are in the business tax taxon.

# %%
btax_content = labelled[labelled['taxon_id'] == btax_id].reset_index()

# %%
btax_content
# Out:
#       index                                          base_path  \
# 0    115137  /government/publications/hidden-economy-unders...
# 1    115138  /government/publications/duty-on-high-strength...
# 2    115139  /government/publications/corporation-tax-refun...
# 3    115140  /government/news/one-million-schemes-use-new-p...
# 4    115141  /government/publications/devolution-of-landfil...
# ..      ...                                                ...
# 517  115654  /government/statistics/companies-and-amount-of...
# 518  115655  /government/publications/directions-under-regu...
# 519  115656  /guidance/seats-furniture-and-other-parts-tari...
# 520  115657  /government/publications/corporation-tax-devol...
# 521  115658  /government/publications/changes-to-personal-c...
#
#                                content_id  \
# 0    5fe7f08a-7631-11e4-a3cb-005056011aef
# 1    5ab5791d-1643-4da8-8647-bff155cefe89
# 2    5d644c95-7631-11e4-a3cb-005056011aef
# 3    5e2ac439-7631-11e4-a3cb-005056011aef
# 4    b1e9af5d-4613-40a0-9532-e8c55f0a23be
# ..                                    ...
# 517  5ebfadb6-7631-11e4-a3cb-005056011aef
# 518  301e7560-7749-4897-a756-93549b7aea91
# 519  b3f7eadc-e827-4d65-b055-c7c8b233079c
# 520  07b02a8e-f40b-4155-8c2b-8e1f10c5d36f
# 521  47ef8235-4240-4996-ae13-c0e3bb796814
#
#                                            description        document_type  \
# 0    research to help hmrc understand and reduce th...             research
# 1    details of the government’s reforms to the tax...         policy_paper
# 2    response to a freedom of information request o...          foi_release
# 3    over one million employer paye schemes have st...           news_story
# 4    legislation will be made to amend the landfill...         policy_paper
# ..                                                 ...                  ...
# 517  the number of enterprise investment scheme (ei...  national_statistics
# 518  directions for users of the making tax digital...         policy_paper
# 519  find out about the tariff classification of se...       detailed_guide
# 520  this tax information and impact note describes...         policy_paper
# 521  this tax information and impact note details n...         policy_paper
#
#                 first_published_at locale primary_publishing_organisation  \
# 0    2012-12-07T00:00:00.000+00:00     en            HM Revenue & Customs
# 1    2017-11-22T13:37:10.000+00:00     en                     HM Treasury
# 2    2011-11-22T00:00:00.000+00:00     en            HM Revenue & Customs
# 3    2013-05-02T12:32:46.000+00:00     en            HM Revenue & Customs
# 4    2017-12-07T08:45:10.000+00:00     en            HM Revenue & Customs
# ..                             ...    ...                             ...
# 517  2013-12-13T09:00:00.000+00:00     en            HM Revenue & Customs
# 518  2018-03-14T14:05:39.000+00:00     en            HM Revenue & Customs
# 519  2018-09-10T23:00:00.000+00:00     en            HM Revenue & Customs
# 520  2015-01-08T13:24:56.000+00:00     en            HM Revenue & Customs
# 521  2018-10-29T16:44:00.000+00:00     en            HM Revenue & Customs
#
#     publishing_app                                              title  \
# 0        whitehall  hidden economy: understanding problems for sma...
# 1        whitehall  duty on high strength ciders: autumn budget 20...
# 2        whitehall      corporation tax refunds between 2006 and 2010
# 3        whitehall            one million schemes use new paye system
# 4        whitehall  devolution of landfill tax to wales and the 2 ...
# ..             ...                                                ...
# 517      whitehall  enterprise investment scheme: number of compan...
# 518      whitehall  directions under regulations 3(3) to 3(6) and ...
# 519      whitehall  seats furniture and other parts (tariff notice...
# 520      whitehall  corporation tax: devolution of rate-setting po...
# 521      whitehall  changes to personal company tests for entrepre...
#
#                                                   body  \
# 0    research report on ways hm revenue and customs...
# 1    following consultation earlier this year autum...
# 2    response to a freedom of information request f...
# 3    the new paye reporting system known as real ti...
# 4    landfill tax will be devolved to wales from 1 ...
# ..                                                 ...
# 517  the information on enterprise investment schem...
# 518  these directions authorise users of the making...
# 519  update to the to the combined nomenclature of ...
# 520  these changes are being introduced following t...
# 521  this document provides more information on the...
#
#                                          combined_text  \
# 0    hidden economy: understanding problems for sma...
# 1    duty on high strength ciders: autumn budget 20...
# 2    corporation tax refunds between 2006 and 2010 ...
# 3    one million schemes use new paye system over o...
# 4    devolution of landfill tax to wales and the 2 ...
# ..                                                 ...
# 517  enterprise investment scheme: number of compan...
# 518  directions under regulations 3(3) to 3(6) and ...
# 519  seats furniture and other parts (tariff notice...
# 520  corporation tax: devolution of rate-setting po...
# 521  changes to personal company tests for entrepre...
#
#                                  taxon_id      taxon_base_path    taxon_name  \
# 0    28262ae3-599c-4259-ae30-3c83a5ec02a1  /money/business-tax  Business tax
# 1    28262ae3-599c-4259-ae30-3c83a5ec02a1  /money/business-tax  Business tax
# 2    28262ae3-599c-4259-ae30-3c83a5ec02a1  /money/business-tax  Business tax
# 3    28262ae3-599c-4259-ae30-3c83a5ec02a1  /money/business-tax  Business tax
# 4    28262ae3-599c-4259-ae30-3c83a5ec02a1  /money/business-tax  Business tax
# ..                                    ...                  ...           ...
# 517  28262ae3-599c-4259-ae30-3c83a5ec02a1  /money/business-tax  Business tax
# 518  28262ae3-599c-4259-ae30-3c83a5ec02a1  /money/business-tax  Business tax
# 519  28262ae3-599c-4259-ae30-3c83a5ec02a1  /money/business-tax  Business tax
# 520  28262ae3-599c-4259-ae30-3c83a5ec02a1  /money/business-tax  Business tax
# 521  28262ae3-599c-4259-ae30-3c83a5ec02a1  /money/business-tax  Business tax
#
#     level1taxon   level2taxon level3taxon level4taxon level5taxon
# 0         Money  Business tax         NaN         NaN         NaN
# 1         Money  Business tax         NaN         NaN         NaN
# 2         Money  Business tax         NaN         NaN         NaN
# 3         Money  Business tax         NaN         NaN         NaN
# 4         Money  Business tax         NaN         NaN         NaN
# ..          ...           ...         ...         ...         ...
# 517       Money  Business tax         NaN         NaN         NaN
# 518       Money  Business tax         NaN         NaN         NaN
# 519       Money  Business tax         NaN         NaN         NaN
# 520       Money  Business tax         NaN         NaN         NaN
# 521       Money  Business tax         NaN         NaN         NaN
#
# [522 rows x 20 columns]

# %% [markdown]
# Now return content items from the data frame where the mean cosine similarity score is above a threshold value. These are the problem content items. Simplify the output to three columns of interest.

# %%
btax_content[['base_path', 'title', 'description']][btax_dist_df['mean'] > 0.65]
# Out:
#                                              base_path  \
# 57   /hmrc-internal-manuals/vat-womens-sanitary-pro...
# 66   /guidance/changes-to-chief-commodity-codes-tar...
# 196  /guidance/rates-and-allowances-for-air-passeng...
# 219  /guidance/air-passenger-duty-and-connected-fli...
# 256  /guidance/rates-and-allowances-for-air-passeng...
# 278  /guidance/poultry-from-iceland-tariff-quota-no...
# 343         /government/publications/iso-country-codes
# 397  /government/news/government-to-waive-vat-on-mi...
# 430  /guidance/laser-skin-treatment-and-hair-remova...
# 478        /government/collections/gwe-rwydo-a-sgamiau
# 513  /government/publications/notice-373-importing-...
#
#                                                  title  \
# 57                       vat women’s sanitary products
# 66   changes to chief commodity codes (tariff stop ...
# 196              historic rates for air passenger duty
# 219           air passenger duty and connected flights
# 256                       rates for air passenger duty
# 278      poultry from iceland (tariff quota notice 73)
# 343                                  iso country codes
# 397  government to waive vat on military wives’ cha...
# 430  laser skin treatment and hair removal (tariff ...
# 478                                gwe-rwydo a sgamiau
# 513  notice 373: importing visual and auditory mate...
#
#                                            description
# 57   guidance on the reduced rate for women's sanit...
# 66   find out the changes to commodity codes in the...
# 196  check which air passenger duty rates apply for...
# 219  check which flights to treat as connected for ...
# 256  check which rates of air passenger duty you ne...
# 278  check the new tariff quota for poultry from ic...
# 343                    find out the iso country codes.
# 397  chancellor of the exchequer has today announce...
# 430  check the tariff classification of electrical ...
# 478  cyngor ar ddiogelwch gan gyllid a thollau em i...
# 513  how to import visual and auditory materials of...

# %% [markdown]
# ## Function to get odd content

# %%
def get_misplaced_content (
    taxon_id = '28262ae3-599c-4259-ae30-3c83a5ec02a1',
    similarity_threshold = 0.65,
    embedded_sentences_data = embedded_sentences,
    labelled_data = labelled
):
    
    """Identify content items that seem out of place in a given taxon.
    The cosine-similarity score (CSS) for each content item is calculated.
    Content items are extracted if their mean score is above a particular threshold (default 0.65).
    """
    
    print('Taxon ID: ', taxon_id)
    print('Similarity threshold:', similarity_threshold)
    
    # Get embeddedings for the specified taxon ID
    taxon_embedded = embedded_sentences[labelled['taxon_id'] == taxon_id]
    
    # Get distances between all content item pairs
    taxon_dist = pairwise_distances(
        taxon_embedded, 
        metric = 'cosine', 
        n_jobs = -1
    )
    
    # As dataframe
    taxon_dist_df = pd.DataFrame(taxon_dist)
    
    # Calculate a mean
    taxon_dist_df['mean'] = taxon_dist.mean(axis = 1)
    
    # Get the rows of the labelled data (content items) that match the taxon ID
    taxon_content = labelled[labelled['taxon_id'] == taxon_id].reset_index()
    
    # Content items that are above the similarity threshold
    misplaced = taxon_content[['content_id', 'base_path', 'title', 'description']][taxon_dist_df['mean'] > similarity_threshold]
    
    return misplaced;

# %%
get_misplaced_content()
# Out:
# Taxon ID:  28262ae3-599c-4259-ae30-3c83a5ec02a1
# Similarity threshold: 0.65
#                                content_id  \
# 57   f9e12f0e-bd0d-5361-8d26-bc83bfb34729
# 66   a211f181-1cc0-45c0-8bb6-0491eb67fc92
# 196  6f019571-54be-4344-aede-cebd901c1fe5
# 219  e110d285-20e0-431e-a394-39edabb2b331
# 256  eb031ebb-7078-4879-a124-33753c4ca0bd
# 278  5f60a446-f47c-403a-aab3-bd83db20cf4f
# 343  6eb3a99b-9a0b-464a-bb42-c08882c7d857
# 397  5d5afda3-7631-11e4-a3cb-005056011aef
# 430  0fea02ed-c1c8-4502-a7a2-f0ebebe1ee1c
# 478  e36ebdbf-b8df-4dc8-beb5-beece2f7b7de
# 513  5fea6d81-7631-11e4-a3cb-005056011aef
#
#                                              base_path  \
# 57   /hmrc-internal-manuals/vat-womens-sanitary-pro...
# 66   /guidance/changes-to-chief-commodity-codes-tar...
# 196  /guidance/rates-and-allowances-for-air-passeng...
# 219  /guidance/air-passenger-duty-and-connected-fli...
# 256  /guidance/rates-and-allowances-for-air-passeng...
# 278  /guidance/poultry-from-iceland-tariff-quota-no...
# 343         /government/publications/iso-country-codes
# 397  /government/news/government-to-waive-vat-on-mi...
# 430  /guidance/laser-skin-treatment-and-hair-remova...
# 478        /government/collections/gwe-rwydo-a-sgamiau
# 513  /government/publications/notice-373-importing-...
#
#                                                  title  \
# 57                       vat women’s sanitary products
# 66   changes to chief commodity codes (tariff stop ...
# 196              historic rates for air passenger duty
# 219           air passenger duty and connected flights
# 256                       rates for air passenger duty
# 278      poultry from iceland (tariff quota notice 73)
# 343                                  iso country codes
# 397  government to waive vat on military wives’ cha...
# 430  laser skin treatment and hair removal (tariff ...
# 478                                gwe-rwydo a sgamiau
# 513  notice 373: importing visual and auditory mate...
#
#                                            description
# 57   guidance on the reduced rate for women's sanit...
# 66   find out the changes to commodity codes in the...
# 196  check which air passenger duty rates apply for...
# 219  check which flights to treat as connected for ...
# 256  check which rates of air passenger duty you ne...
# 278  check the new tariff quota for poultry from ic...
# 343                    find out the iso country codes.
# 397  chancellor of the exchequer has today announce...
# 430  check the tariff classification of electrical ...
# 478  cyngor ar ddiogelwch gan gyllid a thollau em i...
# 513  how to import visual and auditory materials of...

# %%
test

# %% [markdown]
# ## 3. Taxon could be split

# %% [markdown]
# ## 4. Taxon could be merged
